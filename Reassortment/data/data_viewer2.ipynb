# %% [markdown]
# More refined and easy to use data analyzer for reassortment project. Organized well for meta model, not so much for comp model.

# %%
import os
import numpy as np
import pandas
import matplotlib.pyplot as plt
import analysis as ana # file that I made
from importlib import reload
reload(ana)
# %matplotlib inline
# parameters
direc = './test4' # directory you want to graph 
direc2 = './test2'
win = 1 # display winning probability
kmplot = 1 # display kmean vs generation plot: 1=k1&k2, 2=k1, 3=k2
p2print = ['mig','tr','host_num'] # type parameter you want to print out in a list
sortpar = ['tr','mig'] # type parameter you want to sort the order of graphs by.
repcap = [1,1000] # graph certain range of reps (e.g. [0,100]=graph rep=0 to 1000)
histrep = [100] # rep to plot histogram
ana.display(direc,win,kmplot,p2print,sortpar,repcap,histrep)
#ana.display(direc2,win,kmplot,p2print,sortpar)
# Out:
# [1, 0, 50, 0.05, 1000, 1000, 0.06, 1000, 0.0, 0.5, 20, 30, 0.1, 0.01, '2.00']
# m1.1.3s_1,0,50,0.050,1000,1000,0.06000,1000,0.00,0.50,20,30,0.10000,0.01000,2.00(0).csv
# mig=0.1
# tr=0.01
# host_num=30
# reps= 50
# /home/hyunseok/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# num=49
# 2 seg winning prob: 0.000
# endmeank1= -0.9384502222222223
# endmeank2= 2.8803222222222216

# %%
import os
import numpy as np
import pandas
import matplotlib.pyplot as plt
import analysis as ana # file that I made
from importlib import reload
reload(ana)
# %matplotlib inline
#whether you want to see
direc = './test2'
direc2 = './test2'
win = 1 # display winning probability
kmplot = 1 # display kmean vs generation plot: 1=k1&k2, 2=k1, 3=k2
p2print = ['N0','K']# type parameter you want to print out in a list
sortpar = ['K']# type parameter you want to sort the order of graphs by.
repcap = [1,1000] # graph certain range of reps (e.g. [0,100]=graph rep=0 to 1000)
#ana.display(direc,win,kmplot,p2print,sortpar,repcap)
#ana.display(direc2,win,kmplot,p2print,sortpar)
print('hey')
# Out:
# hey

# %%
#data_a = pandas.read_csv(direc+'/'+'m1.1.2s_1,0,100,0.050,1000,1000,0.12000,500,0.00,0.50,20,1(0).csv')
#data_a2 = data_a.loc[data_a['rep']==2]
#plt.subplot(121)
#plt.plot(list(data_a2['k2']),'r',label='k2')
#plt.subplot(122)
#plt.plot(list(data_a2['pop2']))
print(2)
# Out:
# 2
